# %%
#importing all the packages and dependecies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#reading the dataset
credit_card_data= pd.read_csv("C:/Users/GONE SAIKUMAR/OneDrive/Desktop/Sai project/creditcard.csv")

# %%
#displaying top 5 rows
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#displaying bottom 5 rows
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#information of dataset
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#displaying the missing values
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#total number of normal and fraud transactions
credit_card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#separating normal and fraud transactions
normal= credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data.Class==1]

# %%
#after separating normal and fraud txns we are displaying the shape of data
print(normal.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statistical measures of normal data
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#statistical measures of fraud data
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#bar graph between fraud and normal txns
count_classes = pd.value_counts(credit_card_data['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
LABELS = ["Normal", "Fraud"]
plt.title("Transaction Class Distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#comparing the values of normal and fraud txns
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#given data is unbalanced so we will select a random sample of 492 normal txns
normal_sample = normal.sample(n=492)

# %%
#comibining two data frames(normal_sample & fraud),axis=0 is used for rows
new_dataset = pd.concat([normal_sample, fraud], axis=0)

# %%
#displaying top 5 data from new_dataset
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 178991  123876.0 -0.423774  1.064847  2.875685  4.097060  0.234117  2.022519
# 170141  120035.0 -0.592728  1.494597  1.216408  4.095099  0.482921  2.098197
# 142441   84720.0  1.086302 -0.000108  1.413386  1.360207 -0.864766  0.107807
# 177028  123011.0  1.814272 -1.242594 -0.936168 -0.701742  0.023657  1.861587
# 196757  131680.0  1.987921 -0.611527 -0.423927  0.393145 -0.727170 -0.115267
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 178991 -0.452122  0.454919 -0.906388  ...  0.078243  0.499356 -0.377893
# 170141 -0.461071  0.962551 -1.904721  ...  0.299313  0.931683 -0.225034
# 142441 -0.562568  0.152120  0.714584  ... -0.001544  0.282317  0.053069
# 177028 -1.060943  0.539884 -0.123995  ... -0.449405 -0.843300  0.414105
# 196757 -0.854045  0.174594  1.548676  ...  0.136573  0.488558  0.221806
#
# ...

# %%
#displaying bottom 5 data from new_dataset
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
#separating fraud and normal txns
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
#comparing the values for normal_sample and fraud txns
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93397.172764  0.089955 -0.053450  0.022137  0.138554  0.005263
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.108527  0.070938 -0.034553  0.033235  ...  0.042986 -0.014681
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.020270  0.008126 -0.036443  0.037438  0.015411  0.001880  0.032665
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      107.677053
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#splitting data into features(columns)&targets(0&1)
X= new_dataset.drop(columns='Class',axis=1)
Y= new_dataset['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 178991  123876.0 -0.423774  1.064847  2.875685  4.097060  0.234117  2.022519
# 170141  120035.0 -0.592728  1.494597  1.216408  4.095099  0.482921  2.098197
# 142441   84720.0  1.086302 -0.000108  1.413386  1.360207 -0.864766  0.107807
# 177028  123011.0  1.814272 -1.242594 -0.936168 -0.701742  0.023657  1.861587
# 196757  131680.0  1.987921 -0.611527 -0.423927  0.393145 -0.727170 -0.115267
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 178991    0
# 170141    0
# 142441    0
# 177028    0
# 196757    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#splitting data into training and testing
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear')

# %%
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
training_data_accuracy
# Out:
# 0.8881829733163914

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
test_data_accuracy
# Out:
# 0.9086294416243654

# %%
 from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data=scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[ 0.76592407  0.34731165 -0.1933771  ...  0.13774538 -0.22838436
#   -0.39056837]
#  [ 0.68598946  0.31670506 -0.07800592 ...  0.24656892  0.2042321
#   -0.33184728]
#  [-0.04894699  0.62086713 -0.47927655 ...  0.00958705 -0.02952656
#   -0.36210486]
#  ...
#  [ 1.71229913  0.30159416 -0.17686174 ...  0.29996442  0.30246039
#   -0.1278415 ]
#  [ 1.72509782 -0.1400017  -0.32196558 ...  0.8015454  -0.66419598
#    0.44870855]
#  [ 1.73304758  0.78493318 -0.43670279 ... -0.08354156 -0.14988597
#   -0.24983785]]

# %%
X=standardized_data
Y=new_dataset['Class']

# %%
X
# Out:
# array([[ 0.76592407,  0.34731165, -0.1933771 , ...,  0.13774538,
#         -0.22838436, -0.39056837],
#        [ 0.68598946,  0.31670506, -0.07800592, ...,  0.24656892,
#          0.2042321 , -0.33184728],
#        [-0.04894699,  0.62086713, -0.47927655, ...,  0.00958705,
#         -0.02952656, -0.36210486],
#        ...,
#        [ 1.71229913,  0.30159416, -0.17686174, ...,  0.29996442,
#          0.30246039, -0.1278415 ],
#        [ 1.72509782, -0.1400017 , -0.32196558, ...,  0.8015454 ,
#         -0.66419598,  0.44870855],
#        [ 1.73304758,  0.78493318, -0.43670279, ..., -0.08354156,
#         -0.14988597, -0.24983785]])

# %%
Y
# Out:
# 178991    0
# 170141    0
# 142441    0
# 177028    0
# 196757    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# example of making a single class prediction
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=1000000, centers=2, n_features=29, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# define one new instance
Xnew = [[-2.3122265423263,1.95199201064158,-1.60985073229769,3.9979055875468,-0.522187864667764,-1.42654531920595,-2.53738730624579,1.39165724829804,-2.77008927719433,-2.77227214465915,3.20203320709635,-2.89990738849473,-0.595221881324605,-4.28925378244217,0.389724120274487,-1.14074717980657,-2.83005567450437,-0.0168224681808257,0.416955705037907,0.126910559061474,0.517232370861764,-0.0350493686052974,-0.465211076182388,0.320198198514526,0.0445191674731724,0.177839798284401,0.261145002567677,-0.143275874698919,0]]
# make a prediction
Xnew = [[-2.3122265423263,1.95199201064158,-1.60985073229769,3.9979055875468,-0.522187864667764,-1.42654531920595,-2.53738730624579,1.39165724829804,-2.77008927719433,-2.77227214465915,3.20203320709635,-2.89990738849473,-0.595221881324605,-4.28925378244217,0.389724120274487,-1.14074717980657,-2.83005567450437,-0.0168224681808257,0.416955705037907,0.126910559061474,0.517232370861764,-0.0350493686052974,-0.465211076182388,0.320198198514526,0.0445191674731724,0.177839798284401,0.261145002567677,-0.143275874698919,0]]
# make a prediction

ynew = model.predict(Xnew)
print("X=%s, Credit card is:=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[-2.3122265423263, 1.95199201064158, -1.60985073229769, 3.9979055875468, -0.522187864667764, -1.42654531920595, -2.53738730624579, 1.39165724829804, -2.77008927719433, -2.77227214465915, 3.20203320709635, -2.89990738849473, -0.595221881324605, -4.28925378244217, 0.389724120274487, -1.14074717980657, -2.83005567450437, -0.0168224681808257, 0.416955705037907, 0.126910559061474, 0.517232370861764, -0.0350493686052974, -0.465211076182388, 0.320198198514526, 0.0445191674731724, 0.177839798284401, 0.261145002567677, -0.143275874698919, 0], Credit card is:=1

# %%
model.predict([[-2.3122265423263,1.95199201064158,-1.60985073229769,3.9979055875468,-0.522187864667764,-1.42654531920595,-2.53738730624579,1.39165724829804,-2.77008927719433,-2.77227214465915,3.20203320709635,-2.89990738849473,-0.595221881324605,-4.28925378244217,0.389724120274487,-1.14074717980657,-2.83005567450437,-0.0168224681808257,0.416955705037907,0.126910559061474,0.517232370861764,-0.0350493686052974,-0.465211076182388,0.320198198514526,0.0445191674731724,0.177839798284401,0.261145002567677,-0.143275874698919,0]]
)
# Out:
# array([1])
